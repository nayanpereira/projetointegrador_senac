# %%
print("Hello!")
# Out:
# Hello!

# %%
import pandas as pd

# %%
# carregar o dataset
df = pd.read_csv('dados/diabetes.csv', sep=';')

# %%
df.head()
# Out:
#                      ID                  Data      Perfil  Resposta Inicial  \
# 0  PZmOgdfHfS8RCWhsp4Vl  24/02/2026, 19:55:21  management   Diabetes tipo 2
# 1  Lt1wtkPmWdTfSYgLY825  24/02/2026, 19:50:25   screening               Não
# 2  MEthjb3ffwEYWfPIxCJ9  24/02/2026, 19:42:42   screening               Não
# 3  DiP0kKF94ekfpnSbfhUJ  24/02/2026, 19:40:47   screening  Não sei informar
# 4  hTlFOLTHZBZfbhDT2mYu  24/02/2026, 19:40:41   screening      Pré-diabetes
#
#     Peso  Altura    IMC  Pressão Exames Atividade Sede Cicatrizacao Historico  \
# 0   82.0   179.0  25.59   130/90    NaN       NaN  NaN          NaN       NaN
# 1   56.0   156.0  23.01  110x180    Sim       Não  Sim          Não       Não
# 2   94.0   170.0  32.53     12/7    Sim       Sim  Não          Não       Sim
# 3  130.0   180.0  40.12    130/9    Não       Não  Sim          Sim       Sim
# 4   79.0   182.0  23.85      NaN    Não       Não  Não          Não       Sim
#
#   Medicacao
# 0       Sim
# 1       NaN
# ...

# %%
df_descritiva = df.drop(columns=['ID','Perfil'])

# %%
df_descritiva.head()
# Out:
#                    Data  Resposta Inicial   Peso  Altura    IMC  Pressão  \
# 0  24/02/2026, 19:55:21   Diabetes tipo 2   82.0   179.0  25.59   130/90
# 1  24/02/2026, 19:50:25               Não   56.0   156.0  23.01  110x180
# 2  24/02/2026, 19:42:42               Não   94.0   170.0  32.53     12/7
# 3  24/02/2026, 19:40:47  Não sei informar  130.0   180.0  40.12    130/9
# 4  24/02/2026, 19:40:41      Pré-diabetes   79.0   182.0  23.85      NaN
#
#   Exames Atividade Sede Cicatrizacao Historico Medicacao
# 0    NaN       NaN  NaN          NaN       NaN       Sim
# 1    Sim       Não  Sim          Não       Não       NaN
# 2    Sim       Sim  Não          Não       Sim       NaN
# 3    Não       Não  Sim          Sim       Sim       NaN
# 4    Não       Não  Não          Não       Sim       NaN

# %% [markdown]
# # Engenharia de Variáveis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Quantitativas Contínuas: Peso, Altura, IMC, Pressao
# - Quantitativas Discretas: N/A
# - Qualitativas Nominais (sem ordem): RespostaInicial, Exame, Atividade, Sede, Cicatrização, Medicação
# - Qualiativas Ordinais (com ordem): N/A
